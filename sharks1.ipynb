# %%
#importar a los sospechosos habituales
import numpy as np
import pandas as pd

# %%
#importar el csv sobre el que vamos a trabajar
a  = pd.read_csv('attacks.csv', encoding= "ISO-8859-1")
a.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# Vamos a conocer la tabla

# %%
a.shape
# Out:
# (25723, 24)

# %%
a.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
a.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
'''Esto nos cuenta que el ultimo regitstro es de 2018
que el primero es de 1942, y que hay valores 0 en 'Year' , 
la media y la mediana no están igualadas, seguramente hay más
ataques anteriores al 77  . '''
# Out:
# "Esto nos cuenta que el ultimo regitstro es de 2018\nque el primero es de 1942, y que hay valores 0 en 'Year' , \nla media y la mediana no están igualadas, seguramente hay más\nataques anteriores al 77  . "

# %%
a.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
a[sorted(a.columns)]
#ordenarlas de mayor a menor, la idea era por el año, pero más adelante cuando le quite filitas
# Out:
#           Activity  Age             Area Case Number Case Number.1  \
# 0         Paddling   57       California  2018.06.25    2018.06.25
# 1         Standing   11          Georgia  2018.06.18    2018.06.18
# 2          Surfing   48           Hawaii  2018.06.09    2018.06.09
# 3          Surfing  NaN  New South Wales  2018.06.08    2018.06.08
# 4      Free diving  NaN           Colima  2018.06.04    2018.06.04
# ...            ...  ...              ...         ...           ...
# 25718          NaN  NaN              NaN         NaN           NaN
# 25719          NaN  NaN              NaN         NaN           NaN
# 25720          NaN  NaN              NaN         NaN           NaN
# 25721          NaN  NaN              NaN         NaN           NaN
# 25722          NaN  NaN              NaN          xx           NaN
#
#       Case Number.2    Country         Date Fatal (Y/N)  \
# 0        2018.06.25        USA  25-Jun-2018           N
# ...

# %%
a.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
'''de esto asumimos que de 25.000 filas la columna que más
 no nulos tiene, tiene 8.000 valores validos, 
 es decir que hay muchos más valores null que non-null'''
# Out:
# 'de esto asumimos que de 25.000 filas la columna que más\n no nulos tiene, tiene 8.000 valores validos, \n es decir que hay muchos más valores null que non-null'

# %%
# elimino todas las filas vacias

a = a.dropna(how='all')
a.shape
# Out:
# (8703, 24)

# %%
# de 25723 he pasado a 8703

# %%
# elimino las filas duplicadas 
a = a.drop_duplicates()
a.shape

# He pasado de 8703 a 6311
# Out:
# (6311, 24)

# %%
#voy a unificar criterios columna por columna buscando los valores unicos 
# y reemplazando los que no digan nada.
a.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
date_uniquevalues= a['Date'].unique()
len (date_uniquevalues)
# Claro, la fecha es diferente siempre, pero no hay 5.000 años distintos 
# entre los años que han contado casos
# Out:
# 5434

# %%
#o lo mismo no es siempre direrente esa fecha... voy a confirmarlo.

# %%
a['Date'].value_counts().shape[0]
# Out:
# 5433

# %%
# entiendo que no tiene sentido unificar criterios en todas las columnas
'''[ 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23'],
      dtype='object')'''
# Out:
# "[ 'Year', 'Type', 'Country', 'Area', 'Location',\n       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',\n       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',\n       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',\n       'Unnamed: 23'],\n      dtype='object')"

# %%
a.head()
'''huele a que  pdf, href formula , href	Case Number.1	Case Number.2	
original order	Unnamed: 22	Unnamed: 23 no valen para nada
 para unificar
 'Sex '
 'Fatal (Y/N)'
 tal vez 'Species '
'''
# Out:
# "huele a que  pdf, href formula , href\tCase Number.1\tCase Number.2\t\noriginal order\tUnnamed: 22\tUnnamed: 23 no valen para nada\n para unificar\n 'Sex '\n 'Fatal (Y/N)'\n tal vez 'Species '\n"

# %%
a['Sex '].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
#vamos a ver qué es M
M_= a[a['Sex ']=='M ']
M_
# Out:
#      Case Number         Date    Year        Type    Country        Area  \
# 563   2014.04.22  22-Apr-2014  2014.0  Unprovoked        USA     Florida
# 1587  2005.05.15  15-May-2005  2005.0  Unprovoked  AUSTRALIA  Queensland
#
#                           Location      Activity           Name Sex   ...  \
# 563   Cocoa Beach, Brevard  County      Swimming           male   M   ...
# 1587      50 km east of Townsville  Spearfishing  Ben Edelstein   M   ...
#
#             Species                         Investigator or Source  \
# 563              NaN            R. Neale, Florida Today, 4/22/2014
# 1587  Blacktip shark  J. Anderson, Townsville Bulletin, 5/21/2005
#
#                             pdf  \
# 563   2014.04.22-CocoaBeach.pdf
# 1587   2005.05.15-Edelstein.pdf
#
#                                            href formula  \
# 563   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1587  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %%
#es M mal escrito asique lo reemplazo por M
a.Sex .replace({"M ": M})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 #es M mal escrito asique lo reemplazo por M
# ----> 2 a.Sex .replace({"M ": M})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Sex'

# %%
'''No me está dejando cambiarlo creo que por el espacio de detras de sex
voy a cambiar el nombre de las columnas'''
#segundo intento antes de cambiar los nombres de columna

a["Sex "].replace({"M ": "M"}, inplace=True)

# %%
M_
#no deberia seguir existiendo, no entiendo porqué sigue estando
# Out:
#      Case Number         Date    Year        Type    Country        Area  \
# 563   2014.04.22  22-Apr-2014  2014.0  Unprovoked        USA     Florida
# 1587  2005.05.15  15-May-2005  2005.0  Unprovoked  AUSTRALIA  Queensland
#
#                           Location      Activity           Name Sex   ...  \
# 563   Cocoa Beach, Brevard  County      Swimming           male   M   ...
# 1587      50 km east of Townsville  Spearfishing  Ben Edelstein   M   ...
#
#             Species                         Investigator or Source  \
# 563              NaN            R. Neale, Florida Today, 4/22/2014
# 1587  Blacktip shark  J. Anderson, Townsville Bulletin, 5/21/2005
#
#                             pdf  \
# 563   2014.04.22-CocoaBeach.pdf
# 1587   2005.05.15-Edelstein.pdf
#
#                                            href formula  \
# 563   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1587  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %%
lli = a[a['Sex ']=='lli']
lli
# Out:
#        Case Number         Date    Year        Type Country        Area  \
# 1624  2004.11.11.b  11-Nov-2004  2004.0  Unprovoked     USA  California
#
#                                             Location Activity        Name  \
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#      Sex   ...                 Species             Investigator or Source  \
# 1624  lli  ...  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1624  2004.11.11.b-Kang.pdf
#
#                                            href formula  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...  2004.11.11.b
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1624  2004.11.11.b         4679.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
a["Sex "].replace({"lli": "M"}, inplace=True)
lli
# Out:
#        Case Number         Date    Year        Type Country        Area  \
# 1624  2004.11.11.b  11-Nov-2004  2004.0  Unprovoked     USA  California
#
#                                             Location Activity        Name  \
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#      Sex   ...                 Species             Investigator or Source  \
# 1624  lli  ...  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1624  2004.11.11.b-Kang.pdf
#
#                                            href formula  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...  2004.11.11.b
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1624  2004.11.11.b         4679.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
#no debería existir lli, no entiendo
lli_new = a[a['Name']=='Brian Kang']
lli_new
# Out:
#        Case Number         Date    Year        Type Country        Area  \
# 1624  2004.11.11.b  11-Nov-2004  2004.0  Unprovoked     USA  California
#
#                                             Location Activity        Name  \
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#      Sex   ...                 Species             Investigator or Source  \
# 1624    M  ...  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1624  2004.11.11.b-Kang.pdf
#
#                                            href formula  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_di...  2004.11.11.b
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1624  2004.11.11.b         4679.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
#vale, ya entiendo, la variable sigue siendo esa 
# pero en a ya eatá cambiado.
sex_N= a[a['Sex ']=='N']
sex_N
# Out:
#        Case Number                  Date    Year      Type    Country  \
# 4938    1934.07.11           11-Jul-1934  1934.0   Boating  AUSTRALIA
# 6131  1801.12.18.R  Reported 18-Dec-1801  1801.0  Provoked        NaN
#
#                  Area  Location                         Activity  \
# 4938  New South Wales  Cronulla                          Fishing
# 6131              NaN       NaN  Standing on landed shark's tail
#
#                                              Name Sex   ...  \
# 4938  18' boat, occupants William & Leslie Newton    N  ...
# 6131                             Stephen Pettigew    N  ...
#
#                 Species                              Investigator or Source  \
# 4938  Blue pointer, 11'   G.P. Whitley, ref: Daily Telegraph, 7/11/1934 ...
# 6131           12' shark                       The Evening Post, 12/18/1801
#
#                                        pdf  \
# 4938  1934.07.11-Newton-boat-Australia.pdf
# 6131            1801.12.18.R-Pettigrew.pdf
#
# ...

# %%
sex_= a[a['Sex ']=='.']
sex_
# Out:
#        Case Number                  Date    Year          Type  \
# 5437  1908.06.02.R  Reported 02-Jun-1908  1908.0  Sea Disaster
#
#                Country         Area Location Activity Name Sex   ...  \
# 5437  PAPUA NEW GUINEA  New Britain   Matupi        .  NaN    .  ...
#
#                        Species      Investigator or Source  \
# 5437  Allegedly a 33-foot shark  Taranaki Herald, 6/2/1908
#
#                           pdf  \
# 5437  1908.06.02.R-Matupi.pdf
#
#                                            href formula  \
# 5437  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 5437  http://sharkattackfile.net/spreadsheets/pdf_di...  1908.06.02.R
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 5437  1908.06.02.R          866.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
sex_nan= a[a['Sex '].isnull()]
sex_nan[~a['Name'].isnull()]

#la virgula hace de negación, filtro los no nan 
# a ver de los que no tienen sexo y no tienen nombre si son grupos
#o qué son
# Out:
# /var/folders/01/wqv196rd4sx_rrnwlvh6ksq40000gn/T/ipykernel_21247/1053423577.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sex_nan[~a['Name'].isnull()]
#        Case Number                  Date    Year          Type     Country  \
# 59    2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster       LIBYA
# 179   2017.02.01.b           01-Feb-2017  2017.0       Boating         USA
# 218   2016.09.15.R           15-Sep-2016  2016.0       Boating   AUSTRALIA
# 243     2016.07.17           17-Jul-2016  2016.0       Boating         USA
# 297     2016.03.13           13-Mar-2016  2016.0       Invalid         USA
# ...            ...                   ...     ...           ...         ...
# 6167  1617.00.00.R         Reported 1617  1617.0    Unprovoked       INDIA
# 6202       ND-0119           Before 1963     0.0    Unprovoked    DJIBOUTI
# 6212       ND-0107           Before 2004     0.0          Boat  MOZAMBIQUE
# ...

# %%
#no podemos concluir que los que no tienen sexo ni nombre sean grupos
# ponemos los puntos, las n y los nan de sexo como x

# %%
sex_nan[a['Name'].isnull()]
# Out:
# /var/folders/01/wqv196rd4sx_rrnwlvh6ksq40000gn/T/ipykernel_21247/2115447330.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sex_nan[a['Name'].isnull()]
#         Case Number         Date    Year        Type        Country  \
# 32       2018.04.09  09-Apr-2018  2018.0  Unprovoked  NEW CALEDONIA
# 86       2017.09.14     Sep-2017  2017.0     Boating      AUSTRALIA
# 124      2017.07.02  02-Jul-2017  2017.0     Invalid        COMOROS
# 154    2017.04.17.b  17-Apr-2017  2017.0  Unprovoked            USA
# 226      2016.09.00     Sep-2016  2016.0     Invalid         MEXICO
# ...             ...          ...     ...         ...            ...
# 6306              0          NaN     NaN         NaN            NaN
# 6307              0          NaN     NaN         NaN            NaN
# 6308              0          NaN     NaN         NaN            NaN
# 6309              0          NaN     NaN         NaN            NaN
# ...

# %%
a['Sex '].fillna ('x',inplace=True)

# %%
a[a['Sex '].isnull()]
#nan sustituido por x
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
a['Sex '].replace('N','x', inplace=True)

# %%
a['Sex '].replace('.','x', inplace=True)

# %%
#unificados los sex en F, M, x

# %%
caso_0 = a[a['Case Number']== '0']
caso_0
#es todo eliminable
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6307           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6308           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
# 6309           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN    x
#
#       ... Species  Investigator or Source  pdf href formula href  \
# 6302  ...      NaN                    NaN  NaN          NaN  NaN
# 6303  ...      NaN                    NaN  NaN          NaN  NaN
# 6304  ...      NaN                    NaN  NaN          NaN  NaN
# ...

# %%
a[a['Case Number']== '0'].drop(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 a[a['Case Number']== '0'].drop(inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
a = a[['Case Number'] != '0']
#mi intencion es esliminar las filas que contienen 0 
# en el case number porque tienen tono nan, pero no lo estoy consiguiendo.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# ...

# %%
a.dropna(thresh=len(a.columns) / 2, axis=0, inplace=True)
#las que tengan la mitad de la fila con nulo fuera
'''thresh: número mínimo de no-nulos que debe tener una fila para ser conservada
axis: si es 0, borrará filas; si es 1, borrará columnas
inplace: si es True, modificará el DataFrame original, 
si es False, devolverá un DataFrame sin las filas con más de la mitad de nulos.'''

# %%
a.shape
# Out:
# (6302, 24)

# %%
a.dropna(thresh=len(a.columns) / 3, axis=0, inplace=True)

# %%
a.shape
# Out:
# (6302, 24)

# %%
a.dropna(thresh=len(a.columns) / 5, axis=0, inplace=True)

# %%
a.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
def calculate_percentage(row, total_column):
    return 100 * row['x'] / row['total_column']

a['porcentaje'] = a.apply(lambda x: calculate_percentage(x, 'Sex '), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# ...
